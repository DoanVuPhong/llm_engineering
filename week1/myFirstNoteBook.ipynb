# %%
print("Hello world!");
print("This is a test script.");
# Out:
# Hello world!
# This is a test script.

# %%
print(42)         # an integer
print(3.14)       # a float
print(2 + 3)      # math!
# Out:
# 42
# 3.14
# 5

# %%
print(True);
print(False);
print(5>3);
print(2==4);
# Out:
# True
# False
# True
# False

# %%
greeting = "Hello there!";
age = 25;
is_student = True;
print(greeting)
print(age)
print(is_student)
# Out:
# Hello there!
# 25
# True

# %%
age =16;
if age >= 18:
    print("You are an adult.")
elif age >= 13:
    print("You are a teenager.")
else: 
    print("You are a child.")
# Out:
# You are a teenager.

# %%
for i in range(5):
    print("I value is: ", i);

for number in range(1, 6):
    print(number * number)
# Out:
# I value is:  0
# I value is:  1
# I value is:  2
# I value is:  3
# I value is:  4
# 1
# 4
# 9
# 16
# 25

# %%
myAge=18;
myName="Doan";
for i in range(3):
    print("My name is ", myName, " and I am ", myAge, " years old.");

if(myAge < 18):
    print("Please exist this program.");
else:
    print("Welcome to the program, ", myName, "!");

for i in range(1, 11):
    print(i, " squared is ", i*i);
favorite_color="Green";
print("My favorite color is ", favorite_color, ".");
myFirst_String="01_intro.ipynb";
mySecond_String=" 02_variables.ipynb";
print(myFirst_String+mySecond_String);
# Out:
# My name is  Doan  and I am  18  years old.
# My name is  Doan  and I am  18  years old.
# My name is  Doan  and I am  18  years old.
# Welcome to the program,  Doan !
# 1  squared is  1
# 2  squared is  4
# 3  squared is  9
# 4  squared is  16
# 5  squared is  25
# 6  squared is  36
# 7  squared is  49
# 8  squared is  64
# 9  squared is  81
# 10  squared is  100
# My favorite color is  Green .
# 01_intro.ipynb 02_variables.ipynb

# %%
x=0;
while x <5:
    print("The value of x is: ", x);
    x+=1;
# Out:
# The value of x is:  0
# The value of x is:  1
# The value of x is:  2
# The value of x is:  3
# The value of x is:  4

# %%
colors = ["Red", "Green", "Blue"];
print(colors[0]);

for color in colors:
    print("I like", color)
# Out:
# Red
# I like Red
# I like Green
# I like Blue

# %%
person = {
    "name": "Alice",
    "age": 30,
    "city": "New York",
    "is_student" : False}
print("Name:", person["name"])
for key in person:
    print(key, ":", person[key])
# Out:
# Name: Alice
# name : Alice
# age : 30
# city : New York
# is_student : False
